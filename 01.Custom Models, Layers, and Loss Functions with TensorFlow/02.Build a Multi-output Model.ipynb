# %% [markdown]
# # Build a Multi-output Model
#
# Learn to build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 885us/sample - loss: 279.9974 - y1_output_loss: 132.4680 - y2_output_loss: 145.0192 - y1_output_root_mean_squared_error: 11.5607 - y2_output_root_mean_squared_error: 12.0974 - val_loss: 39.4495 - val_y1_output_loss: 17.3612 - val_y2_output_loss: 22.8096 - val_y1_output_root_mean_squared_error: 4.1684 - val_y2_output_root_mean_squared_error: 4.6983
# Epoch 2/500
# 614/614 [==============================] - 0s 139us/sample - loss: 32.2422 - y1_output_loss: 13.0340 - y2_output_loss: 19.0955 - y1_output_root_mean_squared_error: 3.6169 - y2_output_root_mean_squared_error: 4.3772 - val_loss: 26.4102 - val_y1_output_loss: 11.1301 - val_y2_output_loss: 16.7676 - val_y1_output_root_mean_squared_error: 3.2837 - val_y2_output_root_mean_squared_error: 3.9531
# Epoch 3/500
# 614/614 [==============================] - 0s 140us/sample - loss: 23.4477 - y1_output_loss: 10.0730 - y2_output_loss: 13.2685 - y1_output_root_mean_squared_error: 3.1749 - y2_output_root_mean_squared_error: 3.6562 - val_loss: 34.6600 - val_y1_output_loss: 12.3614 - val_y2_output_loss: 24.1660 - val_y1_output_root_mean_squared_error: 3.4592 - val_y2_output_root_mean_squared_error: 4.7638
# Epoch 4/500
# 614/614 [==============================] - 0s 128us/sample - loss: 22.5227 - y1_output_loss: 9.4024 - y2_output_loss: 12.9296 - y1_output_root_mean_squared_error: 3.0779 - y2_output_root_mean_squared_error: 3.6124 - val_loss: 21.0917 - val_y1_output_loss: 8.8593 - val_y2_output_loss: 13.1555 - val_y1_output_root_mean_squared_error: 2.9354 - val_y2_output_root_mean_squared_error: 3.5320
# Epoch 5/500
# 614/614 [==============================] - 0s 127us/sample - loss: 27.5399 - y1_output_loss: 10.0476 - y2_output_loss: 17.7090 - y1_output_root_mean_squared_error: 3.1715 - y2_output_root_mean_squared_error: 4.1811 - val_loss: 22.2194 - val_y1_output_loss: 9.3095 - val_y2_output_loss: 13.6103 - val_y1_output_root_mean_squared_error: 3.0213 - val_y2_output_root_mean_squared_error: 3.6182
# Epoch 6/500
# 614/614 [==============================] - 0s 127us/sample - loss: 21.9381 - y1_output_loss: 9.1430 - y2_output_loss: 12.7825 - y1_output_root_mean_squared_error: 3.0288 - y2_output_root_mean_squared_error: 3.5727 - val_loss: 32.5537 - val_y1_output_loss: 12.5431 - val_y2_output_loss: 21.3229 - val_y1_output_root_mean_squared_error: 3.5087 - val_y2_output_root_mean_squared_error: 4.4992
# Epoch 7/500
# 614/614 [==============================] - 0s 128us/sample - loss: 21.3790 - y1_output_loss: 8.6826 - y2_output_loss: 12.5769 - y1_output_root_mean_squared_error: 2.9578 - y2_output_root_mean_squared_error: 3.5539 - val_loss: 25.1002 - val_y1_output_loss: 8.1944 - val_y2_output_loss: 17.9793 - val_y1_output_root_mean_squared_error: 2.8485 - val_y2_output_root_mean_squared_error: 4.1215
# Epoch 8/500
# 614/614 [==============================] - 0s 131us/sample - loss: 21.2427 - y1_output_loss: 8.5002 - y2_output_loss: 12.7421 - y1_output_root_mean_squared_error: 2.9108 - y2_output_root_mean_squared_error: 3.5735 - val_loss: 27.9632 - val_y1_output_loss: 9.1938 - val_y2_output_loss: 18.4124 - val_y1_output_root_mean_squared_error: 3.0486 - val_y2_output_root_mean_squared_error: 4.3208
# Epoch 9/500
# 614/614 [==============================] - 0s 128us/sample - loss: 20.4401 - y1_output_loss: 8.0306 - y2_output_loss: 12.3332 - y1_output_root_mean_squared_error: 2.8382 - y2_output_root_mean_squared_error: 3.5192 - val_loss: 17.8978 - val_y1_output_loss: 7.2617 - val_y2_output_loss: 11.4895 - val_y1_output_root_mean_squared_error: 2.6573 - val_y2_output_root_mean_squared_error: 3.2919
# Epoch 10/500
# 614/614 [==============================] - 0s 128us/sample - loss: 20.9314 - y1_output_loss: 8.0433 - y2_output_loss: 12.7295 - y1_output_root_mean_squared_error: 2.8478 - y2_output_root_mean_squared_error: 3.5807 - val_loss: 18.4139 - val_y1_output_loss: 7.3736 - val_y2_output_loss: 11.8630 - val_y1_output_root_mean_squared_error: 2.6824 - val_y2_output_root_mean_squared_error: 3.3494
# Epoch 11/500
# 614/614 [==============================] - 0s 128us/sample - loss: 22.9563 - y1_output_loss: 8.6546 - y2_output_loss: 14.4638 - y1_output_root_mean_squared_error: 2.9407 - y2_output_root_mean_squared_error: 3.7827 - val_loss: 24.3388 - val_y1_output_loss: 8.0697 - val_y2_output_loss: 17.2353 - val_y1_output_root_mean_squared_error: 2.8317 - val_y2_output_root_mean_squared_error: 4.0398
# Epoch 12/500
# 614/614 [==============================] - 0s 131us/sample - loss: 20.4256 - y1_output_loss: 8.0980 - y2_output_loss: 12.1599 - y1_output_root_mean_squared_error: 2.8582 - y2_output_root_mean_squared_error: 3.5009 - val_loss: 15.4930 - val_y1_output_loss: 6.2328 - val_y2_output_loss: 9.8400 - val_y1_output_root_mean_squared_error: 2.4906 - val_y2_output_root_mean_squared_error: 3.0479
# Epoch 13/500
# 614/614 [==============================] - 0s 127us/sample - loss: 17.7069 - y1_output_loss: 7.2784 - y2_output_loss: 10.6328 - y1_output_root_mean_squared_error: 2.6967 - y2_output_root_mean_squared_error: 3.2303 - val_loss: 43.3253 - val_y1_output_loss: 9.0070 - val_y2_output_loss: 33.0015 - val_y1_output_root_mean_squared_error: 3.0347 - val_y2_output_root_mean_squared_error: 5.8409
# Epoch 14/500
# 614/614 [==============================] - 0s 127us/sample - loss: 20.4563 - y1_output_loss: 7.5787 - y2_output_loss: 12.6918 - y1_output_root_mean_squared_error: 2.7655 - y2_output_root_mean_squared_error: 3.5789 - val_loss: 23.0822 - val_y1_output_loss: 7.8042 - val_y2_output_loss: 16.4278 - val_y1_output_root_mean_squared_error: 2.7637 - val_y2_output_root_mean_squared_error: 3.9299
# Epoch 15/500
# 614/614 [==============================] - 0s 127us/sample - loss: 19.0696 - y1_output_loss: 7.4732 - y2_output_loss: 11.4928 - y1_output_root_mean_squared_error: 2.7396 - y2_output_root_mean_squared_error: 3.4006 - val_loss: 14.7599 - val_y1_output_loss: 5.7774 - val_y2_output_loss: 9.5117 - val_y1_output_root_mean_squared_error: 2.4159 - val_y2_output_root_mean_squared_error: 2.9872
# Epoch 16/500
# 614/614 [==============================] - 0s 125us/sample - loss: 16.4189 - y1_output_loss: 6.6517 - y2_output_loss: 9.6645 - y1_output_root_mean_squared_error: 2.5915 - y2_output_root_mean_squared_error: 3.1150 - val_loss: 18.7473 - val_y1_output_loss: 6.2750 - val_y2_output_loss: 13.3956 - val_y1_output_root_mean_squared_error: 2.4897 - val_y2_output_root_mean_squared_error: 3.5424
# Epoch 17/500
# 614/614 [==============================] - 0s 126us/sample - loss: 14.5292 - y1_output_loss: 6.0506 - y2_output_loss: 8.5699 - y1_output_root_mean_squared_error: 2.4541 - y2_output_root_mean_squared_error: 2.9166 - val_loss: 13.9958 - val_y1_output_loss: 5.1941 - val_y2_output_loss: 8.8195 - val_y1_output_root_mean_squared_error: 2.2874 - val_y2_output_root_mean_squared_error: 2.9603
# Epoch 18/500
# 614/614 [==============================] - 0s 130us/sample - loss: 19.5591 - y1_output_loss: 6.9733 - y2_output_loss: 12.5088 - y1_output_root_mean_squared_error: 2.6479 - y2_output_root_mean_squared_error: 3.5423 - val_loss: 12.8579 - val_y1_output_loss: 4.9273 - val_y2_output_loss: 8.2332 - val_y1_output_root_mean_squared_error: 2.2183 - val_y2_output_root_mean_squared_error: 2.8173
# Epoch 19/500
# 614/614 [==============================] - 0s 126us/sample - loss: 13.1792 - y1_output_loss: 5.5059 - y2_output_loss: 7.5777 - y1_output_root_mean_squared_error: 2.3529 - y2_output_root_mean_squared_error: 2.7646 - val_loss: 13.1603 - val_y1_output_loss: 4.7686 - val_y2_output_loss: 8.9807 - val_y1_output_root_mean_squared_error: 2.1766 - val_y2_output_root_mean_squared_error: 2.9022
# Epoch 20/500
# 614/614 [==============================] - 0s 125us/sample - loss: 15.0998 - y1_output_loss: 5.6478 - y2_output_loss: 9.8105 - y1_output_root_mean_squared_error: 2.3635 - y2_output_root_mean_squared_error: 3.0844 - val_loss: 41.8036 - val_y1_output_loss: 10.9113 - val_y2_output_loss: 29.4023 - val_y1_output_root_mean_squared_error: 3.3582 - val_y2_output_root_mean_squared_error: 5.5250
# Epoch 21/500
# 614/614 [==============================] - 0s 129us/sample - loss: 17.8792 - y1_output_loss: 6.1565 - y2_output_loss: 11.8817 - y1_output_root_mean_squared_error: 2.4768 - y2_output_root_mean_squared_error: 3.4271 - val_loss: 60.6830 - val_y1_output_loss: 13.2165 - val_y2_output_loss: 45.3127 - val_y1_output_root_mean_squared_error: 3.6992 - val_y2_output_root_mean_squared_error: 6.8556
# Epoch 22/500
# 614/614 [==============================] - 0s 126us/sample - loss: 18.1447 - y1_output_loss: 6.2469 - y2_output_loss: 11.8184 - y1_output_root_mean_squared_error: 2.4963 - y2_output_root_mean_squared_error: 3.4516 - val_loss: 11.9864 - val_y1_output_loss: 4.5603 - val_y2_output_loss: 7.4381 - val_y1_output_root_mean_squared_error: 2.1628 - val_y2_output_root_mean_squared_error: 2.7034
# Epoch 23/500
# 614/614 [==============================] - 0s 126us/sample - loss: 13.1318 - y1_output_loss: 5.1585 - y2_output_loss: 8.0160 - y1_output_root_mean_squared_error: 2.2757 - y2_output_root_mean_squared_error: 2.8201 - val_loss: 31.6708 - val_y1_output_loss: 6.1398 - val_y2_output_loss: 24.3833 - val_y1_output_root_mean_squared_error: 2.5226 - val_y2_output_root_mean_squared_error: 5.0307
# Epoch 24/500
# 614/614 [==============================] - 0s 126us/sample - loss: 11.8157 - y1_output_loss: 4.4061 - y2_output_loss: 7.3099 - y1_output_root_mean_squared_error: 2.1068 - y2_output_root_mean_squared_error: 2.7161 - val_loss: 11.5295 - val_y1_output_loss: 4.6285 - val_y2_output_loss: 6.7723 - val_y1_output_root_mean_squared_error: 2.1878 - val_y2_output_root_mean_squared_error: 2.5967
# Epoch 25/500
# 614/614 [==============================] - 0s 126us/sample - loss: 11.7184 - y1_output_loss: 4.4788 - y2_output_loss: 7.1550 - y1_output_root_mean_squared_error: 2.1212 - y2_output_root_mean_squared_error: 2.6868 - val_loss: 12.6759 - val_y1_output_loss: 4.5887 - val_y2_output_loss: 8.4417 - val_y1_output_root_mean_squared_error: 2.1486 - val_y2_output_root_mean_squared_error: 2.8389
# Epoch 26/500
# 614/614 [==============================] - 0s 126us/sample - loss: 13.6188 - y1_output_loss: 4.9731 - y2_output_loss: 8.5662 - y1_output_root_mean_squared_error: 2.2357 - y2_output_root_mean_squared_error: 2.9360 - val_loss: 22.3634 - val_y1_output_loss: 5.9189 - val_y2_output_loss: 16.7471 - val_y1_output_root_mean_squared_error: 2.4542 - val_y2_output_root_mean_squared_error: 4.0423
# Epoch 27/500
# 614/614 [==============================] - 0s 128us/sample - loss: 13.3136 - y1_output_loss: 4.3746 - y2_output_loss: 8.9355 - y1_output_root_mean_squared_error: 2.0898 - y2_output_root_mean_squared_error: 2.9910 - val_loss: 23.0432 - val_y1_output_loss: 6.4219 - val_y2_output_loss: 15.8461 - val_y1_output_root_mean_squared_error: 2.5795 - val_y2_output_root_mean_squared_error: 4.0484
# Epoch 28/500
# 614/614 [==============================] - 0s 126us/sample - loss: 10.5757 - y1_output_loss: 4.0906 - y2_output_loss: 6.4499 - y1_output_root_mean_squared_error: 2.0191 - y2_output_root_mean_squared_error: 2.5493 - val_loss: 27.0354 - val_y1_output_loss: 10.8425 - val_y2_output_loss: 16.3398 - val_y1_output_root_mean_squared_error: 3.3182 - val_y2_output_root_mean_squared_error: 4.0031
# Epoch 29/500
# 614/614 [==============================] - 0s 126us/sample - loss: 11.6188 - y1_output_loss: 4.3108 - y2_output_loss: 7.3457 - y1_output_root_mean_squared_error: 2.0781 - y2_output_root_mean_squared_error: 2.7019 - val_loss: 14.7140 - val_y1_output_loss: 5.5006 - val_y2_output_loss: 8.8936 - val_y1_output_root_mean_squared_error: 2.3821 - val_y2_output_root_mean_squared_error: 3.0066
# Epoch 30/500
# 614/614 [==============================] - 0s 126us/sample - loss: 11.6152 - y1_output_loss: 4.2364 - y2_output_loss: 7.2944 - y1_output_root_mean_squared_error: 2.0640 - y2_output_root_mean_squared_error: 2.7120 - val_loss: 10.0980 - val_y1_output_loss: 3.8649 - val_y2_output_loss: 6.2613 - val_y1_output_root_mean_squared_error: 1.9869 - val_y2_output_root_mean_squared_error: 2.4800
# Epoch 31/500
# 614/614 [==============================] - 0s 128us/sample - loss: 9.9683 - y1_output_loss: 3.9008 - y2_output_loss: 6.0451 - y1_output_root_mean_squared_error: 1.9740 - y2_output_root_mean_squared_error: 2.4641 - val_loss: 23.3560 - val_y1_output_loss: 8.4968 - val_y2_output_loss: 14.9489 - val_y1_output_root_mean_squared_error: 2.9432 - val_y2_output_root_mean_squared_error: 3.8333
# Epoch 32/500
# 614/614 [==============================] - 0s 127us/sample - loss: 9.7251 - y1_output_loss: 3.5590 - y2_output_loss: 6.1387 - y1_output_root_mean_squared_error: 1.8885 - y2_output_root_mean_squared_error: 2.4817 - val_loss: 13.2025 - val_y1_output_loss: 4.2069 - val_y2_output_loss: 8.5874 - val_y1_output_root_mean_squared_error: 2.0892 - val_y2_output_root_mean_squared_error: 2.9728
# Epoch 33/500
# 614/614 [==============================] - 0s 126us/sample - loss: 9.5015 - y1_output_loss: 3.4886 - y2_output_loss: 5.9368 - y1_output_root_mean_squared_error: 1.8758 - y2_output_root_mean_squared_error: 2.4460 - val_loss: 13.5022 - val_y1_output_loss: 4.6956 - val_y2_output_loss: 8.8749 - val_y1_output_root_mean_squared_error: 2.1934 - val_y2_output_root_mean_squared_error: 2.9480
# Epoch 34/500
# 614/614 [==============================] - 0s 127us/sample - loss: 10.3504 - y1_output_loss: 3.7653 - y2_output_loss: 6.5564 - y1_output_root_mean_squared_error: 1.9327 - y2_output_root_mean_squared_error: 2.5720 - val_loss: 11.5651 - val_y1_output_loss: 3.9721 - val_y2_output_loss: 7.7093 - val_y1_output_root_mean_squared_error: 2.0152 - val_y2_output_root_mean_squared_error: 2.7393
# Epoch 35/500
# 614/614 [==============================] - 0s 126us/sample - loss: 8.8542 - y1_output_loss: 3.0720 - y2_output_loss: 5.7411 - y1_output_root_mean_squared_error: 1.7495 - y2_output_root_mean_squared_error: 2.4069 - val_loss: 13.4789 - val_y1_output_loss: 4.6809 - val_y2_output_loss: 8.8776 - val_y1_output_root_mean_squared_error: 2.1896 - val_y2_output_root_mean_squared_error: 2.9470
# Epoch 36/500
# 614/614 [==============================] - 0s 126us/sample - loss: 10.5148 - y1_output_loss: 3.7984 - y2_output_loss: 6.6435 - y1_output_root_mean_squared_error: 1.9535 - y2_output_root_mean_squared_error: 2.5882 - val_loss: 9.2650 - val_y1_output_loss: 3.1982 - val_y2_output_loss: 5.9753 - val_y1_output_root_mean_squared_error: 1.8159 - val_y2_output_root_mean_squared_error: 2.4428
# Epoch 37/500
# 614/614 [==============================] - 0s 126us/sample - loss: 9.9987 - y1_output_loss: 3.3274 - y2_output_loss: 6.6368 - y1_output_root_mean_squared_error: 1.8247 - y2_output_root_mean_squared_error: 2.5825 - val_loss: 8.9197 - val_y1_output_loss: 2.7018 - val_y2_output_loss: 6.2519 - val_y1_output_root_mean_squared_error: 1.6713 - val_y2_output_root_mean_squared_error: 2.4751
# Epoch 38/500
# 614/614 [==============================] - 0s 127us/sample - loss: 8.5682 - y1_output_loss: 2.9202 - y2_output_loss: 5.8080 - y1_output_root_mean_squared_error: 1.7005 - y2_output_root_mean_squared_error: 2.3826 - val_loss: 20.0859 - val_y1_output_loss: 6.1594 - val_y2_output_loss: 13.9882 - val_y1_output_root_mean_squared_error: 2.5120 - val_y2_output_root_mean_squared_error: 3.7116
# Epoch 39/500
# 614/614 [==============================] - 0s 127us/sample - loss: 8.6589 - y1_output_loss: 3.0379 - y2_output_loss: 5.6218 - y1_output_root_mean_squared_error: 1.7493 - y2_output_root_mean_squared_error: 2.3662 - val_loss: 8.2356 - val_y1_output_loss: 2.9764 - val_y2_output_loss: 5.2023 - val_y1_output_root_mean_squared_error: 1.7491 - val_y2_output_root_mean_squared_error: 2.2751
# Epoch 40/500
# 614/614 [==============================] - 0s 128us/sample - loss: 8.6773 - y1_output_loss: 2.9024 - y2_output_loss: 5.9339 - y1_output_root_mean_squared_error: 1.6925 - y2_output_root_mean_squared_error: 2.4109 - val_loss: 22.8222 - val_y1_output_loss: 6.4144 - val_y2_output_loss: 16.5181 - val_y1_output_root_mean_squared_error: 2.5611 - val_y2_output_root_mean_squared_error: 4.0328
# Epoch 41/500
# 614/614 [==============================] - 0s 128us/sample - loss: 8.2667 - y1_output_loss: 2.7144 - y2_output_loss: 5.4867 - y1_output_root_mean_squared_error: 1.6535 - y2_output_root_mean_squared_error: 2.3521 - val_loss: 8.0944 - val_y1_output_loss: 2.8601 - val_y2_output_loss: 5.2354 - val_y1_output_root_mean_squared_error: 1.7111 - val_y2_output_root_mean_squared_error: 2.2730
# Epoch 42/500
# 614/614 [==============================] - 0s 127us/sample - loss: 8.8921 - y1_output_loss: 3.0054 - y2_output_loss: 5.9839 - y1_output_root_mean_squared_error: 1.7321 - y2_output_root_mean_squared_error: 2.4274 - val_loss: 32.7875 - val_y1_output_loss: 11.6515 - val_y2_output_loss: 20.0762 - val_y1_output_root_mean_squared_error: 3.4598 - val_y2_output_root_mean_squared_error: 4.5626
# Epoch 43/500
# 614/614 [==============================] - 0s 129us/sample - loss: 12.2193 - y1_output_loss: 4.0503 - y2_output_loss: 8.2092 - y1_output_root_mean_squared_error: 1.9939 - y2_output_root_mean_squared_error: 2.8712 - val_loss: 13.0494 - val_y1_output_loss: 4.4359 - val_y2_output_loss: 8.5459 - val_y1_output_root_mean_squared_error: 2.1400 - val_y2_output_root_mean_squared_error: 2.9103
# Epoch 44/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.0435 - y1_output_loss: 2.4587 - y2_output_loss: 4.5407 - y1_output_root_mean_squared_error: 1.5722 - y2_output_root_mean_squared_error: 2.1381 - val_loss: 7.5685 - val_y1_output_loss: 2.7884 - val_y2_output_loss: 4.6742 - val_y1_output_root_mean_squared_error: 1.6899 - val_y2_output_root_mean_squared_error: 2.1709
# Epoch 45/500
# 614/614 [==============================] - 0s 125us/sample - loss: 10.1387 - y1_output_loss: 3.1665 - y2_output_loss: 7.0821 - y1_output_root_mean_squared_error: 1.7569 - y2_output_root_mean_squared_error: 2.6555 - val_loss: 7.7102 - val_y1_output_loss: 2.5635 - val_y2_output_loss: 5.1936 - val_y1_output_root_mean_squared_error: 1.6231 - val_y2_output_root_mean_squared_error: 2.2529
# Epoch 46/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.6546 - y1_output_loss: 2.2315 - y2_output_loss: 4.4745 - y1_output_root_mean_squared_error: 1.4859 - y2_output_root_mean_squared_error: 2.1088 - val_loss: 12.5337 - val_y1_output_loss: 3.9424 - val_y2_output_loss: 8.6067 - val_y1_output_root_mean_squared_error: 2.0146 - val_y2_output_root_mean_squared_error: 2.9112
# Epoch 47/500
# 614/614 [==============================] - 0s 127us/sample - loss: 9.2856 - y1_output_loss: 2.7261 - y2_output_loss: 6.4704 - y1_output_root_mean_squared_error: 1.6590 - y2_output_root_mean_squared_error: 2.5560 - val_loss: 7.6924 - val_y1_output_loss: 2.5581 - val_y2_output_loss: 5.0726 - val_y1_output_root_mean_squared_error: 1.6260 - val_y2_output_root_mean_squared_error: 2.2469
# Epoch 48/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.9249 - y1_output_loss: 2.3629 - y2_output_loss: 4.5517 - y1_output_root_mean_squared_error: 1.5373 - y2_output_root_mean_squared_error: 2.1358 - val_loss: 7.5867 - val_y1_output_loss: 2.6465 - val_y2_output_loss: 4.8349 - val_y1_output_root_mean_squared_error: 1.6553 - val_y2_output_root_mean_squared_error: 2.2016
# Epoch 49/500
# 614/614 [==============================] - 0s 125us/sample - loss: 7.5160 - y1_output_loss: 2.5241 - y2_output_loss: 5.0068 - y1_output_root_mean_squared_error: 1.5844 - y2_output_root_mean_squared_error: 2.2373 - val_loss: 12.7348 - val_y1_output_loss: 3.9226 - val_y2_output_loss: 8.7474 - val_y1_output_root_mean_squared_error: 2.0134 - val_y2_output_root_mean_squared_error: 2.9463
# Epoch 50/500
# 614/614 [==============================] - 0s 126us/sample - loss: 7.5451 - y1_output_loss: 2.5872 - y2_output_loss: 5.0014 - y1_output_root_mean_squared_error: 1.6120 - y2_output_root_mean_squared_error: 2.2241 - val_loss: 18.8480 - val_y1_output_loss: 3.7275 - val_y2_output_loss: 14.4909 - val_y1_output_root_mean_squared_error: 1.9542 - val_y2_output_root_mean_squared_error: 3.8767
# Epoch 51/500
# 614/614 [==============================] - 0s 126us/sample - loss: 9.1148 - y1_output_loss: 2.7859 - y2_output_loss: 6.3406 - y1_output_root_mean_squared_error: 1.6731 - y2_output_root_mean_squared_error: 2.5131 - val_loss: 15.3195 - val_y1_output_loss: 3.4086 - val_y2_output_loss: 11.4526 - val_y1_output_root_mean_squared_error: 1.8692 - val_y2_output_root_mean_squared_error: 3.4388
# Epoch 52/500
# 614/614 [==============================] - 0s 125us/sample - loss: 7.6772 - y1_output_loss: 2.3146 - y2_output_loss: 5.3579 - y1_output_root_mean_squared_error: 1.5249 - y2_output_root_mean_squared_error: 2.3134 - val_loss: 6.4308 - val_y1_output_loss: 2.1963 - val_y2_output_loss: 4.1239 - val_y1_output_root_mean_squared_error: 1.5071 - val_y2_output_root_mean_squared_error: 2.0395
# Epoch 53/500
# 614/614 [==============================] - 0s 126us/sample - loss: 6.5301 - y1_output_loss: 1.9815 - y2_output_loss: 4.5824 - y1_output_root_mean_squared_error: 1.4031 - y2_output_root_mean_squared_error: 2.1358 - val_loss: 6.6972 - val_y1_output_loss: 2.4028 - val_y2_output_loss: 4.2625 - val_y1_output_root_mean_squared_error: 1.5703 - val_y2_output_root_mean_squared_error: 2.0570
# Epoch 54/500
# 614/614 [==============================] - 0s 126us/sample - loss: 6.3072 - y1_output_loss: 1.8810 - y2_output_loss: 4.4013 - y1_output_root_mean_squared_error: 1.3778 - y2_output_root_mean_squared_error: 2.0998 - val_loss: 6.7126 - val_y1_output_loss: 2.2206 - val_y2_output_loss: 4.3051 - val_y1_output_root_mean_squared_error: 1.5037 - val_y2_output_root_mean_squared_error: 2.1098
# Epoch 55/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.7690 - y1_output_loss: 1.9503 - y2_output_loss: 3.8269 - y1_output_root_mean_squared_error: 1.3955 - y2_output_root_mean_squared_error: 1.9549 - val_loss: 19.9104 - val_y1_output_loss: 6.3207 - val_y2_output_loss: 13.5159 - val_y1_output_root_mean_squared_error: 2.5507 - val_y2_output_root_mean_squared_error: 3.6612
# Epoch 56/500
# 614/614 [==============================] - 0s 128us/sample - loss: 10.2964 - y1_output_loss: 3.3069 - y2_output_loss: 7.0003 - y1_output_root_mean_squared_error: 1.8196 - y2_output_root_mean_squared_error: 2.6430 - val_loss: 12.5201 - val_y1_output_loss: 4.9617 - val_y2_output_loss: 7.4268 - val_y1_output_root_mean_squared_error: 2.2653 - val_y2_output_root_mean_squared_error: 2.7181
# Epoch 57/500
# 614/614 [==============================] - 0s 128us/sample - loss: 8.2521 - y1_output_loss: 2.4666 - y2_output_loss: 5.7564 - y1_output_root_mean_squared_error: 1.5743 - y2_output_root_mean_squared_error: 2.4029 - val_loss: 6.5638 - val_y1_output_loss: 2.1529 - val_y2_output_loss: 4.2744 - val_y1_output_root_mean_squared_error: 1.4842 - val_y2_output_root_mean_squared_error: 2.0883
# Epoch 58/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.6909 - y1_output_loss: 1.8287 - y2_output_loss: 3.8270 - y1_output_root_mean_squared_error: 1.3565 - y2_output_root_mean_squared_error: 1.9623 - val_loss: 10.0721 - val_y1_output_loss: 2.6623 - val_y2_output_loss: 7.4021 - val_y1_output_root_mean_squared_error: 1.6602 - val_y2_output_root_mean_squared_error: 2.7048
# Epoch 59/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.7046 - y1_output_loss: 1.7833 - y2_output_loss: 3.8723 - y1_output_root_mean_squared_error: 1.3406 - y2_output_root_mean_squared_error: 1.9767 - val_loss: 5.3626 - val_y1_output_loss: 1.6865 - val_y2_output_loss: 3.6139 - val_y1_output_root_mean_squared_error: 1.3177 - val_y2_output_root_mean_squared_error: 1.9042
# Epoch 60/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.3789 - y1_output_loss: 2.0452 - y2_output_loss: 4.3471 - y1_output_root_mean_squared_error: 1.4278 - y2_output_root_mean_squared_error: 2.0833 - val_loss: 9.7154 - val_y1_output_loss: 3.9308 - val_y2_output_loss: 5.5408 - val_y1_output_root_mean_squared_error: 2.0131 - val_y2_output_root_mean_squared_error: 2.3796
# Epoch 61/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.2753 - y1_output_loss: 2.3897 - y2_output_loss: 4.8441 - y1_output_root_mean_squared_error: 1.5456 - y2_output_root_mean_squared_error: 2.2105 - val_loss: 5.7951 - val_y1_output_loss: 1.8840 - val_y2_output_loss: 3.8378 - val_y1_output_root_mean_squared_error: 1.3865 - val_y2_output_root_mean_squared_error: 1.9680
# Epoch 62/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.6805 - y1_output_loss: 1.7250 - y2_output_loss: 3.9540 - y1_output_root_mean_squared_error: 1.3197 - y2_output_root_mean_squared_error: 1.9847 - val_loss: 7.6107 - val_y1_output_loss: 1.9358 - val_y2_output_loss: 5.4880 - val_y1_output_root_mean_squared_error: 1.4072 - val_y2_output_root_mean_squared_error: 2.3728
# Epoch 63/500
# 614/614 [==============================] - 0s 125us/sample - loss: 5.9864 - y1_output_loss: 1.9142 - y2_output_loss: 4.0408 - y1_output_root_mean_squared_error: 1.3861 - y2_output_root_mean_squared_error: 2.0162 - val_loss: 7.2172 - val_y1_output_loss: 2.6270 - val_y2_output_loss: 4.4281 - val_y1_output_root_mean_squared_error: 1.6384 - val_y2_output_root_mean_squared_error: 2.1290
# Epoch 64/500
# 614/614 [==============================] - 0s 125us/sample - loss: 5.1620 - y1_output_loss: 1.5327 - y2_output_loss: 3.5836 - y1_output_root_mean_squared_error: 1.2435 - y2_output_root_mean_squared_error: 1.9015 - val_loss: 5.9078 - val_y1_output_loss: 1.8006 - val_y2_output_loss: 4.0905 - val_y1_output_root_mean_squared_error: 1.3638 - val_y2_output_root_mean_squared_error: 2.0119
# Epoch 65/500
# 614/614 [==============================] - 0s 125us/sample - loss: 5.2056 - y1_output_loss: 1.6002 - y2_output_loss: 3.6466 - y1_output_root_mean_squared_error: 1.2628 - y2_output_root_mean_squared_error: 1.9003 - val_loss: 7.2595 - val_y1_output_loss: 2.6880 - val_y2_output_loss: 4.4941 - val_y1_output_root_mean_squared_error: 1.6686 - val_y2_output_root_mean_squared_error: 2.1155
# Epoch 66/500
# 614/614 [==============================] - 0s 125us/sample - loss: 5.2705 - y1_output_loss: 1.7706 - y2_output_loss: 3.5144 - y1_output_root_mean_squared_error: 1.3178 - y2_output_root_mean_squared_error: 1.8798 - val_loss: 14.1336 - val_y1_output_loss: 5.2115 - val_y2_output_loss: 8.9426 - val_y1_output_root_mean_squared_error: 2.3097 - val_y2_output_root_mean_squared_error: 2.9663
# Epoch 67/500
# 614/614 [==============================] - 0s 125us/sample - loss: 5.8410 - y1_output_loss: 1.8258 - y2_output_loss: 3.9882 - y1_output_root_mean_squared_error: 1.3573 - y2_output_root_mean_squared_error: 1.9997 - val_loss: 5.4264 - val_y1_output_loss: 1.6927 - val_y2_output_loss: 3.6454 - val_y1_output_root_mean_squared_error: 1.3143 - val_y2_output_root_mean_squared_error: 1.9233
# Epoch 68/500
# 614/614 [==============================] - 0s 124us/sample - loss: 5.8277 - y1_output_loss: 1.7795 - y2_output_loss: 4.0244 - y1_output_root_mean_squared_error: 1.3389 - y2_output_root_mean_squared_error: 2.0087 - val_loss: 10.7660 - val_y1_output_loss: 1.8974 - val_y2_output_loss: 8.9774 - val_y1_output_root_mean_squared_error: 1.3998 - val_y2_output_root_mean_squared_error: 2.9676
# Epoch 69/500
# 614/614 [==============================] - 0s 124us/sample - loss: 5.6107 - y1_output_loss: 1.7709 - y2_output_loss: 3.8778 - y1_output_root_mean_squared_error: 1.3328 - y2_output_root_mean_squared_error: 1.9582 - val_loss: 13.9877 - val_y1_output_loss: 2.8502 - val_y2_output_loss: 10.6771 - val_y1_output_root_mean_squared_error: 1.7059 - val_y2_output_root_mean_squared_error: 3.3283
# Epoch 70/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.9639 - y1_output_loss: 1.4990 - y2_output_loss: 3.4266 - y1_output_root_mean_squared_error: 1.2297 - y2_output_root_mean_squared_error: 1.8579 - val_loss: 7.8261 - val_y1_output_loss: 2.3070 - val_y2_output_loss: 5.5364 - val_y1_output_root_mean_squared_error: 1.5399 - val_y2_output_root_mean_squared_error: 2.3356
# Epoch 71/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.0923 - y1_output_loss: 2.5927 - y2_output_loss: 5.4548 - y1_output_root_mean_squared_error: 1.6178 - y2_output_root_mean_squared_error: 2.3399 - val_loss: 8.1370 - val_y1_output_loss: 2.6272 - val_y2_output_loss: 5.2983 - val_y1_output_root_mean_squared_error: 1.6262 - val_y2_output_root_mean_squared_error: 2.3436
# Epoch 72/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.6104 - y1_output_loss: 1.4629 - y2_output_loss: 3.1251 - y1_output_root_mean_squared_error: 1.2074 - y2_output_root_mean_squared_error: 1.7755 - val_loss: 5.1965 - val_y1_output_loss: 1.7403 - val_y2_output_loss: 3.4715 - val_y1_output_root_mean_squared_error: 1.3328 - val_y2_output_root_mean_squared_error: 1.8493
# Epoch 73/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.4626 - y1_output_loss: 1.3094 - y2_output_loss: 3.1320 - y1_output_root_mean_squared_error: 1.1461 - y2_output_root_mean_squared_error: 1.7746 - val_loss: 8.0761 - val_y1_output_loss: 2.6138 - val_y2_output_loss: 5.4510 - val_y1_output_root_mean_squared_error: 1.6445 - val_y2_output_root_mean_squared_error: 2.3177
# Epoch 74/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.9063 - y1_output_loss: 1.4833 - y2_output_loss: 3.4067 - y1_output_root_mean_squared_error: 1.2225 - y2_output_root_mean_squared_error: 1.8471 - val_loss: 7.1647 - val_y1_output_loss: 1.7185 - val_y2_output_loss: 5.4858 - val_y1_output_root_mean_squared_error: 1.3271 - val_y2_output_root_mean_squared_error: 2.3245
# Epoch 75/500
# 614/614 [==============================] - 0s 130us/sample - loss: 9.7502 - y1_output_loss: 3.3393 - y2_output_loss: 6.3187 - y1_output_root_mean_squared_error: 1.8359 - y2_output_root_mean_squared_error: 2.5258 - val_loss: 4.6236 - val_y1_output_loss: 1.4231 - val_y2_output_loss: 3.1951 - val_y1_output_root_mean_squared_error: 1.2139 - val_y2_output_root_mean_squared_error: 1.7748
# Epoch 76/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.3621 - y1_output_loss: 1.3997 - y2_output_loss: 2.9714 - y1_output_root_mean_squared_error: 1.1678 - y2_output_root_mean_squared_error: 1.7316 - val_loss: 4.7848 - val_y1_output_loss: 1.5850 - val_y2_output_loss: 3.1960 - val_y1_output_root_mean_squared_error: 1.2809 - val_y2_output_root_mean_squared_error: 1.7732
# Epoch 77/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.5993 - y1_output_loss: 1.5530 - y2_output_loss: 4.0481 - y1_output_root_mean_squared_error: 1.2475 - y2_output_root_mean_squared_error: 2.0107 - val_loss: 5.8814 - val_y1_output_loss: 1.5425 - val_y2_output_loss: 4.2229 - val_y1_output_root_mean_squared_error: 1.2599 - val_y2_output_root_mean_squared_error: 2.0722
# Epoch 78/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.9838 - y1_output_loss: 1.7464 - y2_output_loss: 4.2448 - y1_output_root_mean_squared_error: 1.3189 - y2_output_root_mean_squared_error: 2.0601 - val_loss: 12.0848 - val_y1_output_loss: 5.0559 - val_y2_output_loss: 7.1210 - val_y1_output_root_mean_squared_error: 2.2424 - val_y2_output_root_mean_squared_error: 2.6564
# Epoch 79/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.1616 - y1_output_loss: 1.4691 - y2_output_loss: 3.6717 - y1_output_root_mean_squared_error: 1.2102 - y2_output_root_mean_squared_error: 1.9228 - val_loss: 5.1851 - val_y1_output_loss: 1.6867 - val_y2_output_loss: 3.5945 - val_y1_output_root_mean_squared_error: 1.3032 - val_y2_output_root_mean_squared_error: 1.8673
# Epoch 80/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.3281 - y1_output_loss: 1.3445 - y2_output_loss: 2.9777 - y1_output_root_mean_squared_error: 1.1571 - y2_output_root_mean_squared_error: 1.7289 - val_loss: 6.5453 - val_y1_output_loss: 2.1112 - val_y2_output_loss: 4.4644 - val_y1_output_root_mean_squared_error: 1.4767 - val_y2_output_root_mean_squared_error: 2.0891
# Epoch 81/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.3711 - y1_output_loss: 1.0045 - y2_output_loss: 2.4110 - y1_output_root_mean_squared_error: 0.9990 - y2_output_root_mean_squared_error: 1.5405 - val_loss: 5.6867 - val_y1_output_loss: 1.5728 - val_y2_output_loss: 3.9557 - val_y1_output_root_mean_squared_error: 1.2660 - val_y2_output_root_mean_squared_error: 2.0209
# Epoch 82/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.6154 - y1_output_loss: 1.0315 - y2_output_loss: 2.5572 - y1_output_root_mean_squared_error: 1.0185 - y2_output_root_mean_squared_error: 1.6056 - val_loss: 4.4513 - val_y1_output_loss: 1.6069 - val_y2_output_loss: 2.8482 - val_y1_output_root_mean_squared_error: 1.2899 - val_y2_output_root_mean_squared_error: 1.6696
# Epoch 83/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.1476 - y1_output_loss: 1.4451 - y2_output_loss: 3.6779 - y1_output_root_mean_squared_error: 1.2017 - y2_output_root_mean_squared_error: 1.9244 - val_loss: 4.3925 - val_y1_output_loss: 1.6340 - val_y2_output_loss: 2.7781 - val_y1_output_root_mean_squared_error: 1.2853 - val_y2_output_root_mean_squared_error: 1.6555
# Epoch 84/500
# 614/614 [==============================] - 0s 125us/sample - loss: 5.2992 - y1_output_loss: 1.5141 - y2_output_loss: 3.7637 - y1_output_root_mean_squared_error: 1.2356 - y2_output_root_mean_squared_error: 1.9423 - val_loss: 8.4942 - val_y1_output_loss: 1.8456 - val_y2_output_loss: 6.3776 - val_y1_output_root_mean_squared_error: 1.3795 - val_y2_output_root_mean_squared_error: 2.5673
# Epoch 85/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.1424 - y1_output_loss: 1.1080 - y2_output_loss: 3.0608 - y1_output_root_mean_squared_error: 1.0546 - y2_output_root_mean_squared_error: 1.7407 - val_loss: 5.7037 - val_y1_output_loss: 1.6608 - val_y2_output_loss: 3.9082 - val_y1_output_root_mean_squared_error: 1.3033 - val_y2_output_root_mean_squared_error: 2.0013
# Epoch 86/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.7584 - y1_output_loss: 1.3420 - y2_output_loss: 3.4795 - y1_output_root_mean_squared_error: 1.1371 - y2_output_root_mean_squared_error: 1.8616 - val_loss: 9.4902 - val_y1_output_loss: 4.4805 - val_y2_output_loss: 4.8789 - val_y1_output_root_mean_squared_error: 2.1334 - val_y2_output_root_mean_squared_error: 2.2224
# Epoch 87/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.0438 - y1_output_loss: 1.1313 - y2_output_loss: 2.8853 - y1_output_root_mean_squared_error: 1.0682 - y2_output_root_mean_squared_error: 1.7038 - val_loss: 4.1207 - val_y1_output_loss: 1.2563 - val_y2_output_loss: 2.8679 - val_y1_output_root_mean_squared_error: 1.1378 - val_y2_output_root_mean_squared_error: 1.6811
# Epoch 88/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.8861 - y1_output_loss: 1.3001 - y2_output_loss: 3.5509 - y1_output_root_mean_squared_error: 1.1453 - y2_output_root_mean_squared_error: 1.8906 - val_loss: 3.4969 - val_y1_output_loss: 1.0980 - val_y2_output_loss: 2.4051 - val_y1_output_root_mean_squared_error: 1.0525 - val_y2_output_root_mean_squared_error: 1.5457
# Epoch 89/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.8187 - y1_output_loss: 0.7747 - y2_output_loss: 2.0276 - y1_output_root_mean_squared_error: 0.8798 - y2_output_root_mean_squared_error: 1.4299 - val_loss: 3.7951 - val_y1_output_loss: 1.3848 - val_y2_output_loss: 2.4225 - val_y1_output_root_mean_squared_error: 1.1950 - val_y2_output_root_mean_squared_error: 1.5385
# Epoch 90/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.7604 - y1_output_loss: 0.6757 - y2_output_loss: 2.0677 - y1_output_root_mean_squared_error: 0.8245 - y2_output_root_mean_squared_error: 1.4424 - val_loss: 3.2272 - val_y1_output_loss: 0.9461 - val_y2_output_loss: 2.2992 - val_y1_output_root_mean_squared_error: 0.9795 - val_y2_output_root_mean_squared_error: 1.5059
# Epoch 91/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.9824 - y1_output_loss: 0.7733 - y2_output_loss: 2.1873 - y1_output_root_mean_squared_error: 0.8829 - y2_output_root_mean_squared_error: 1.4842 - val_loss: 4.2300 - val_y1_output_loss: 1.3126 - val_y2_output_loss: 2.9444 - val_y1_output_root_mean_squared_error: 1.1631 - val_y2_output_root_mean_squared_error: 1.6963
# Epoch 92/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.1772 - y1_output_loss: 0.7905 - y2_output_loss: 2.4335 - y1_output_root_mean_squared_error: 0.8905 - y2_output_root_mean_squared_error: 1.5441 - val_loss: 12.6896 - val_y1_output_loss: 2.2542 - val_y2_output_loss: 10.1549 - val_y1_output_root_mean_squared_error: 1.5039 - val_y2_output_root_mean_squared_error: 3.2292
# Epoch 93/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.3691 - y1_output_loss: 0.8963 - y2_output_loss: 2.4485 - y1_output_root_mean_squared_error: 0.9499 - y2_output_root_mean_squared_error: 1.5706 - val_loss: 3.8085 - val_y1_output_loss: 1.2242 - val_y2_output_loss: 2.6709 - val_y1_output_root_mean_squared_error: 1.1129 - val_y2_output_root_mean_squared_error: 1.6031
# Epoch 94/500
# 614/614 [==============================] - 0s 125us/sample - loss: 3.0956 - y1_output_loss: 0.8356 - y2_output_loss: 2.2659 - y1_output_root_mean_squared_error: 0.9117 - y2_output_root_mean_squared_error: 1.5048 - val_loss: 3.6008 - val_y1_output_loss: 0.7870 - val_y2_output_loss: 2.7546 - val_y1_output_root_mean_squared_error: 0.8916 - val_y2_output_root_mean_squared_error: 1.6751
# Epoch 95/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.7078 - y1_output_loss: 0.7039 - y2_output_loss: 2.0241 - y1_output_root_mean_squared_error: 0.8424 - y2_output_root_mean_squared_error: 1.4136 - val_loss: 7.3923 - val_y1_output_loss: 1.0232 - val_y2_output_loss: 6.5245 - val_y1_output_root_mean_squared_error: 1.0297 - val_y2_output_root_mean_squared_error: 2.5163
# Epoch 96/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.6973 - y1_output_loss: 1.2441 - y2_output_loss: 3.5844 - y1_output_root_mean_squared_error: 1.0924 - y2_output_root_mean_squared_error: 1.8719 - val_loss: 78.0393 - val_y1_output_loss: 25.2558 - val_y2_output_loss: 52.7429 - val_y1_output_root_mean_squared_error: 5.0716 - val_y2_output_root_mean_squared_error: 7.2331
# Epoch 97/500
# 614/614 [==============================] - 0s 128us/sample - loss: 33.2237 - y1_output_loss: 11.5331 - y2_output_loss: 21.4346 - y1_output_root_mean_squared_error: 3.4097 - y2_output_root_mean_squared_error: 4.6474 - val_loss: 12.1647 - val_y1_output_loss: 2.9286 - val_y2_output_loss: 9.3593 - val_y1_output_root_mean_squared_error: 1.7395 - val_y2_output_root_mean_squared_error: 3.0230
# Epoch 98/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.8928 - y1_output_loss: 0.8353 - y2_output_loss: 2.0572 - y1_output_root_mean_squared_error: 0.9175 - y2_output_root_mean_squared_error: 1.4321 - val_loss: 3.8857 - val_y1_output_loss: 1.2784 - val_y2_output_loss: 2.6030 - val_y1_output_root_mean_squared_error: 1.1479 - val_y2_output_root_mean_squared_error: 1.6025
# Epoch 99/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.1881 - y1_output_loss: 0.7854 - y2_output_loss: 2.3772 - y1_output_root_mean_squared_error: 0.8898 - y2_output_root_mean_squared_error: 1.5480 - val_loss: 3.0305 - val_y1_output_loss: 0.9021 - val_y2_output_loss: 2.2013 - val_y1_output_root_mean_squared_error: 0.9633 - val_y2_output_root_mean_squared_error: 1.4500
# Epoch 100/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.6688 - y1_output_loss: 0.6968 - y2_output_loss: 1.9881 - y1_output_root_mean_squared_error: 0.8352 - y2_output_root_mean_squared_error: 1.4040 - val_loss: 3.2774 - val_y1_output_loss: 0.9883 - val_y2_output_loss: 2.3023 - val_y1_output_root_mean_squared_error: 1.0067 - val_y2_output_root_mean_squared_error: 1.5047
# Epoch 101/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.6473 - y1_output_loss: 0.7226 - y2_output_loss: 1.9297 - y1_output_root_mean_squared_error: 0.8515 - y2_output_root_mean_squared_error: 1.3865 - val_loss: 4.0126 - val_y1_output_loss: 1.4938 - val_y2_output_loss: 2.5531 - val_y1_output_root_mean_squared_error: 1.2343 - val_y2_output_root_mean_squared_error: 1.5777
# Epoch 102/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.0180 - y1_output_loss: 0.7387 - y2_output_loss: 2.2730 - y1_output_root_mean_squared_error: 0.8516 - y2_output_root_mean_squared_error: 1.5142 - val_loss: 2.6689 - val_y1_output_loss: 0.7379 - val_y2_output_loss: 1.9593 - val_y1_output_root_mean_squared_error: 0.8619 - val_y2_output_root_mean_squared_error: 1.3878
# Epoch 103/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.6496 - y1_output_loss: 0.6693 - y2_output_loss: 2.0270 - y1_output_root_mean_squared_error: 0.7974 - y2_output_root_mean_squared_error: 1.4191 - val_loss: 12.1768 - val_y1_output_loss: 3.7691 - val_y2_output_loss: 8.3864 - val_y1_output_root_mean_squared_error: 1.9754 - val_y2_output_root_mean_squared_error: 2.8766
# Epoch 104/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.2711 - y1_output_loss: 0.9554 - y2_output_loss: 2.3088 - y1_output_root_mean_squared_error: 0.9815 - y2_output_root_mean_squared_error: 1.5191 - val_loss: 4.0839 - val_y1_output_loss: 0.7137 - val_y2_output_loss: 3.5158 - val_y1_output_root_mean_squared_error: 0.8580 - val_y2_output_root_mean_squared_error: 1.8297
# Epoch 105/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.2515 - y1_output_loss: 0.6234 - y2_output_loss: 1.6414 - y1_output_root_mean_squared_error: 0.7904 - y2_output_root_mean_squared_error: 1.2754 - val_loss: 3.6313 - val_y1_output_loss: 0.5829 - val_y2_output_loss: 3.1823 - val_y1_output_root_mean_squared_error: 0.7691 - val_y2_output_root_mean_squared_error: 1.7435
# Epoch 106/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.3137 - y1_output_loss: 0.5918 - y2_output_loss: 1.7120 - y1_output_root_mean_squared_error: 0.7727 - y2_output_root_mean_squared_error: 1.3102 - val_loss: 2.5974 - val_y1_output_loss: 0.6143 - val_y2_output_loss: 2.0478 - val_y1_output_root_mean_squared_error: 0.7942 - val_y2_output_root_mean_squared_error: 1.4024
# Epoch 107/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.0676 - y1_output_loss: 0.5016 - y2_output_loss: 1.5566 - y1_output_root_mean_squared_error: 0.7094 - y2_output_root_mean_squared_error: 1.2507 - val_loss: 2.4428 - val_y1_output_loss: 0.5985 - val_y2_output_loss: 1.8989 - val_y1_output_root_mean_squared_error: 0.7790 - val_y2_output_root_mean_squared_error: 1.3550
# Epoch 108/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.2247 - y1_output_loss: 0.6157 - y2_output_loss: 1.6438 - y1_output_root_mean_squared_error: 0.7824 - y2_output_root_mean_squared_error: 1.2699 - val_loss: 5.1368 - val_y1_output_loss: 1.4030 - val_y2_output_loss: 3.6167 - val_y1_output_root_mean_squared_error: 1.1953 - val_y2_output_root_mean_squared_error: 1.9256
# Epoch 109/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.5854 - y1_output_loss: 0.6411 - y2_output_loss: 1.9602 - y1_output_root_mean_squared_error: 0.8011 - y2_output_root_mean_squared_error: 1.3942 - val_loss: 3.5302 - val_y1_output_loss: 0.6698 - val_y2_output_loss: 3.0071 - val_y1_output_root_mean_squared_error: 0.8137 - val_y2_output_root_mean_squared_error: 1.6936
# Epoch 110/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.0719 - y1_output_loss: 0.5268 - y2_output_loss: 1.5363 - y1_output_root_mean_squared_error: 0.7263 - y2_output_root_mean_squared_error: 1.2427 - val_loss: 4.7289 - val_y1_output_loss: 1.1989 - val_y2_output_loss: 3.4179 - val_y1_output_root_mean_squared_error: 1.0973 - val_y2_output_root_mean_squared_error: 1.8774
# Epoch 111/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.8029 - y1_output_loss: 0.7062 - y2_output_loss: 2.0733 - y1_output_root_mean_squared_error: 0.8435 - y2_output_root_mean_squared_error: 1.4462 - val_loss: 2.2472 - val_y1_output_loss: 0.5489 - val_y2_output_loss: 1.7256 - val_y1_output_root_mean_squared_error: 0.7459 - val_y2_output_root_mean_squared_error: 1.3003
# Epoch 112/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.0725 - y1_output_loss: 0.5341 - y2_output_loss: 1.5454 - y1_output_root_mean_squared_error: 0.7334 - y2_output_root_mean_squared_error: 1.2388 - val_loss: 2.4150 - val_y1_output_loss: 0.5716 - val_y2_output_loss: 1.8962 - val_y1_output_root_mean_squared_error: 0.7590 - val_y2_output_root_mean_squared_error: 1.3560
# Epoch 113/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.5056 - y1_output_loss: 0.5875 - y2_output_loss: 1.9392 - y1_output_root_mean_squared_error: 0.7680 - y2_output_root_mean_squared_error: 1.3841 - val_loss: 6.0859 - val_y1_output_loss: 0.7814 - val_y2_output_loss: 5.1136 - val_y1_output_root_mean_squared_error: 0.8825 - val_y2_output_root_mean_squared_error: 2.3037
# Epoch 114/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.9723 - y1_output_loss: 0.9728 - y2_output_loss: 2.9680 - y1_output_root_mean_squared_error: 0.9897 - y2_output_root_mean_squared_error: 1.7300 - val_loss: 2.6955 - val_y1_output_loss: 0.5437 - val_y2_output_loss: 2.2536 - val_y1_output_root_mean_squared_error: 0.7455 - val_y2_output_root_mean_squared_error: 1.4628
# Epoch 115/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.0640 - y1_output_loss: 0.7528 - y2_output_loss: 2.2837 - y1_output_root_mean_squared_error: 0.8709 - y2_output_root_mean_squared_error: 1.5184 - val_loss: 2.7589 - val_y1_output_loss: 0.7170 - val_y2_output_loss: 2.0205 - val_y1_output_root_mean_squared_error: 0.8472 - val_y2_output_root_mean_squared_error: 1.4287
# Epoch 116/500
# 614/614 [==============================] - 0s 129us/sample - loss: 1.9737 - y1_output_loss: 0.4983 - y2_output_loss: 1.4724 - y1_output_root_mean_squared_error: 0.7035 - y2_output_root_mean_squared_error: 1.2161 - val_loss: 2.1988 - val_y1_output_loss: 0.5095 - val_y2_output_loss: 1.7011 - val_y1_output_root_mean_squared_error: 0.7140 - val_y2_output_root_mean_squared_error: 1.2996
# Epoch 117/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.1611 - y1_output_loss: 0.5951 - y2_output_loss: 1.5638 - y1_output_root_mean_squared_error: 0.7729 - y2_output_root_mean_squared_error: 1.2505 - val_loss: 2.8227 - val_y1_output_loss: 0.7359 - val_y2_output_loss: 2.0663 - val_y1_output_root_mean_squared_error: 0.8592 - val_y2_output_root_mean_squared_error: 1.4437
# Epoch 118/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.7389 - y1_output_loss: 0.6926 - y2_output_loss: 2.0247 - y1_output_root_mean_squared_error: 0.8349 - y2_output_root_mean_squared_error: 1.4289 - val_loss: 2.3819 - val_y1_output_loss: 0.5923 - val_y2_output_loss: 1.8099 - val_y1_output_root_mean_squared_error: 0.7766 - val_y2_output_root_mean_squared_error: 1.3337
# Epoch 119/500
# 614/614 [==============================] - 0s 128us/sample - loss: 1.9867 - y1_output_loss: 0.4507 - y2_output_loss: 1.5653 - y1_output_root_mean_squared_error: 0.6721 - y2_output_root_mean_squared_error: 1.2389 - val_loss: 9.4927 - val_y1_output_loss: 1.5256 - val_y2_output_loss: 8.1087 - val_y1_output_root_mean_squared_error: 1.2550 - val_y2_output_root_mean_squared_error: 2.8138
# Epoch 120/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.0789 - y1_output_loss: 0.8806 - y2_output_loss: 2.1869 - y1_output_root_mean_squared_error: 0.9397 - y2_output_root_mean_squared_error: 1.4818 - val_loss: 3.1956 - val_y1_output_loss: 0.6372 - val_y2_output_loss: 2.6640 - val_y1_output_root_mean_squared_error: 0.8061 - val_y2_output_root_mean_squared_error: 1.5956
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3642 - y1_output_loss: 0.1269 - y2_output_loss: 0.2402 - y1_output_root_mean_squared_error: 0.3562 - y2_output_root_mean_squared_error: 0.4871 - val_loss: 1.0940 - val_y1_output_loss: 0.1730 - val_y2_output_loss: 0.8901 - val_y1_output_root_mean_squared_error: 0.4145 - val_y2_output_root_mean_squared_error: 0.9603
# Epoch 462/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3312 - y1_output_loss: 0.1108 - y2_output_loss: 0.2183 - y1_output_root_mean_squared_error: 0.3342 - y2_output_root_mean_squared_error: 0.4686 - val_loss: 0.8250 - val_y1_output_loss: 0.1897 - val_y2_output_loss: 0.6210 - val_y1_output_root_mean_squared_error: 0.4316 - val_y2_output_root_mean_squared_error: 0.7992
# Epoch 463/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.6024 - y1_output_loss: 0.1788 - y2_output_loss: 0.4375 - y1_output_root_mean_squared_error: 0.4173 - y2_output_root_mean_squared_error: 0.6544 - val_loss: 1.4747 - val_y1_output_loss: 0.3738 - val_y2_output_loss: 1.0731 - val_y1_output_root_mean_squared_error: 0.6090 - val_y2_output_root_mean_squared_error: 1.0506
# Epoch 464/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3716 - y1_output_loss: 0.1238 - y2_output_loss: 0.2462 - y1_output_root_mean_squared_error: 0.3522 - y2_output_root_mean_squared_error: 0.4975 - val_loss: 0.7970 - val_y1_output_loss: 0.1712 - val_y2_output_loss: 0.6232 - val_y1_output_root_mean_squared_error: 0.4063 - val_y2_output_root_mean_squared_error: 0.7950
# Epoch 465/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.3384 - y1_output_loss: 0.1177 - y2_output_loss: 0.2206 - y1_output_root_mean_squared_error: 0.3435 - y2_output_root_mean_squared_error: 0.4695 - val_loss: 0.8858 - val_y1_output_loss: 0.1784 - val_y2_output_loss: 0.7148 - val_y1_output_root_mean_squared_error: 0.4219 - val_y2_output_root_mean_squared_error: 0.8413
# Epoch 466/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3422 - y1_output_loss: 0.1265 - y2_output_loss: 0.2161 - y1_output_root_mean_squared_error: 0.3564 - y2_output_root_mean_squared_error: 0.4639 - val_loss: 1.3407 - val_y1_output_loss: 0.3994 - val_y2_output_loss: 0.9184 - val_y1_output_root_mean_squared_error: 0.6281 - val_y2_output_root_mean_squared_error: 0.9727
# Epoch 467/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3504 - y1_output_loss: 0.1299 - y2_output_loss: 0.2185 - y1_output_root_mean_squared_error: 0.3619 - y2_output_root_mean_squared_error: 0.4685 - val_loss: 0.7504 - val_y1_output_loss: 0.1782 - val_y2_output_loss: 0.5615 - val_y1_output_root_mean_squared_error: 0.4218 - val_y2_output_root_mean_squared_error: 0.7566
# Epoch 468/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3314 - y1_output_loss: 0.1320 - y2_output_loss: 0.2049 - y1_output_root_mean_squared_error: 0.3604 - y2_output_root_mean_squared_error: 0.4489 - val_loss: 2.1821 - val_y1_output_loss: 0.5459 - val_y2_output_loss: 1.6247 - val_y1_output_root_mean_squared_error: 0.7256 - val_y2_output_root_mean_squared_error: 1.2867
# Epoch 469/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3593 - y1_output_loss: 0.1324 - y2_output_loss: 0.2257 - y1_output_root_mean_squared_error: 0.3643 - y2_output_root_mean_squared_error: 0.4760 - val_loss: 0.7289 - val_y1_output_loss: 0.1695 - val_y2_output_loss: 0.5554 - val_y1_output_root_mean_squared_error: 0.4115 - val_y2_output_root_mean_squared_error: 0.7480
# Epoch 470/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.4375 - y1_output_loss: 0.1467 - y2_output_loss: 0.2912 - y1_output_root_mean_squared_error: 0.3809 - y2_output_root_mean_squared_error: 0.5408 - val_loss: 1.2565 - val_y1_output_loss: 0.4222 - val_y2_output_loss: 0.8582 - val_y1_output_root_mean_squared_error: 0.6435 - val_y2_output_root_mean_squared_error: 0.9178
# Epoch 471/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.4093 - y1_output_loss: 0.1394 - y2_output_loss: 0.2668 - y1_output_root_mean_squared_error: 0.3741 - y2_output_root_mean_squared_error: 0.5190 - val_loss: 0.7347 - val_y1_output_loss: 0.1982 - val_y2_output_loss: 0.5334 - val_y1_output_root_mean_squared_error: 0.4461 - val_y2_output_root_mean_squared_error: 0.7319
# Epoch 472/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3962 - y1_output_loss: 0.1386 - y2_output_loss: 0.2547 - y1_output_root_mean_squared_error: 0.3741 - y2_output_root_mean_squared_error: 0.5062 - val_loss: 0.8313 - val_y1_output_loss: 0.1624 - val_y2_output_loss: 0.6643 - val_y1_output_root_mean_squared_error: 0.3988 - val_y2_output_root_mean_squared_error: 0.8199
# Epoch 473/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3611 - y1_output_loss: 0.1336 - y2_output_loss: 0.2266 - y1_output_root_mean_squared_error: 0.3651 - y2_output_root_mean_squared_error: 0.4773 - val_loss: 1.0154 - val_y1_output_loss: 0.2498 - val_y2_output_loss: 0.7583 - val_y1_output_root_mean_squared_error: 0.4935 - val_y2_output_root_mean_squared_error: 0.8786
# Epoch 474/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.4262 - y1_output_loss: 0.1451 - y2_output_loss: 0.2788 - y1_output_root_mean_squared_error: 0.3820 - y2_output_root_mean_squared_error: 0.5294 - val_loss: 0.7326 - val_y1_output_loss: 0.1674 - val_y2_output_loss: 0.5758 - val_y1_output_root_mean_squared_error: 0.4032 - val_y2_output_root_mean_squared_error: 0.7550
# Epoch 475/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3388 - y1_output_loss: 0.1204 - y2_output_loss: 0.2158 - y1_output_root_mean_squared_error: 0.3481 - y2_output_root_mean_squared_error: 0.4665 - val_loss: 0.9047 - val_y1_output_loss: 0.2020 - val_y2_output_loss: 0.6833 - val_y1_output_root_mean_squared_error: 0.4472 - val_y2_output_root_mean_squared_error: 0.8395
# Epoch 476/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3301 - y1_output_loss: 0.1223 - y2_output_loss: 0.2090 - y1_output_root_mean_squared_error: 0.3491 - y2_output_root_mean_squared_error: 0.4563 - val_loss: 0.9056 - val_y1_output_loss: 0.1657 - val_y2_output_loss: 0.7492 - val_y1_output_root_mean_squared_error: 0.4051 - val_y2_output_root_mean_squared_error: 0.8611
# Epoch 477/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.2893 - y1_output_loss: 0.1138 - y2_output_loss: 0.1780 - y1_output_root_mean_squared_error: 0.3359 - y2_output_root_mean_squared_error: 0.4201 - val_loss: 1.7332 - val_y1_output_loss: 0.3653 - val_y2_output_loss: 1.3177 - val_y1_output_root_mean_squared_error: 0.6052 - val_y2_output_root_mean_squared_error: 1.1692
# Epoch 478/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3843 - y1_output_loss: 0.1177 - y2_output_loss: 0.2678 - y1_output_root_mean_squared_error: 0.3390 - y2_output_root_mean_squared_error: 0.5190 - val_loss: 1.0896 - val_y1_output_loss: 0.1795 - val_y2_output_loss: 0.8837 - val_y1_output_root_mean_squared_error: 0.4196 - val_y2_output_root_mean_squared_error: 0.9558
# Epoch 479/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.2967 - y1_output_loss: 0.1156 - y2_output_loss: 0.1809 - y1_output_root_mean_squared_error: 0.3409 - y2_output_root_mean_squared_error: 0.4249 - val_loss: 0.8599 - val_y1_output_loss: 0.1887 - val_y2_output_loss: 0.6651 - val_y1_output_root_mean_squared_error: 0.4284 - val_y2_output_root_mean_squared_error: 0.8224
# Epoch 480/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3657 - y1_output_loss: 0.1236 - y2_output_loss: 0.2444 - y1_output_root_mean_squared_error: 0.3524 - y2_output_root_mean_squared_error: 0.4914 - val_loss: 1.0042 - val_y1_output_loss: 0.1767 - val_y2_output_loss: 0.8073 - val_y1_output_root_mean_squared_error: 0.4138 - val_y2_output_root_mean_squared_error: 0.9126
# Epoch 481/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4176 - y1_output_loss: 0.1523 - y2_output_loss: 0.2641 - y1_output_root_mean_squared_error: 0.3902 - y2_output_root_mean_squared_error: 0.5151 - val_loss: 0.7533 - val_y1_output_loss: 0.1769 - val_y2_output_loss: 0.5887 - val_y1_output_root_mean_squared_error: 0.4144 - val_y2_output_root_mean_squared_error: 0.7626
# Epoch 482/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3318 - y1_output_loss: 0.1179 - y2_output_loss: 0.2129 - y1_output_root_mean_squared_error: 0.3441 - y2_output_root_mean_squared_error: 0.4620 - val_loss: 0.7591 - val_y1_output_loss: 0.1660 - val_y2_output_loss: 0.6185 - val_y1_output_root_mean_squared_error: 0.4015 - val_y2_output_root_mean_squared_error: 0.7732
# Epoch 483/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3815 - y1_output_loss: 0.1409 - y2_output_loss: 0.2472 - y1_output_root_mean_squared_error: 0.3725 - y2_output_root_mean_squared_error: 0.4927 - val_loss: 1.6833 - val_y1_output_loss: 0.3247 - val_y2_output_loss: 1.3197 - val_y1_output_root_mean_squared_error: 0.5655 - val_y2_output_root_mean_squared_error: 1.1677
# Epoch 484/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4859 - y1_output_loss: 0.1424 - y2_output_loss: 0.3412 - y1_output_root_mean_squared_error: 0.3778 - y2_output_root_mean_squared_error: 0.5858 - val_loss: 0.9200 - val_y1_output_loss: 0.2306 - val_y2_output_loss: 0.7111 - val_y1_output_root_mean_squared_error: 0.4769 - val_y2_output_root_mean_squared_error: 0.8322
# Epoch 485/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3669 - y1_output_loss: 0.1267 - y2_output_loss: 0.2477 - y1_output_root_mean_squared_error: 0.3514 - y2_output_root_mean_squared_error: 0.4933 - val_loss: 2.6205 - val_y1_output_loss: 0.8457 - val_y2_output_loss: 1.7710 - val_y1_output_root_mean_squared_error: 0.9323 - val_y2_output_root_mean_squared_error: 1.3233
# Epoch 486/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.6989 - y1_output_loss: 0.1912 - y2_output_loss: 0.5037 - y1_output_root_mean_squared_error: 0.4381 - y2_output_root_mean_squared_error: 0.7121 - val_loss: 0.8227 - val_y1_output_loss: 0.1959 - val_y2_output_loss: 0.6106 - val_y1_output_root_mean_squared_error: 0.4398 - val_y2_output_root_mean_squared_error: 0.7933
# Epoch 487/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4012 - y1_output_loss: 0.1293 - y2_output_loss: 0.2689 - y1_output_root_mean_squared_error: 0.3608 - y2_output_root_mean_squared_error: 0.5206 - val_loss: 0.7311 - val_y1_output_loss: 0.1665 - val_y2_output_loss: 0.5636 - val_y1_output_root_mean_squared_error: 0.4031 - val_y2_output_root_mean_squared_error: 0.7540
# Epoch 488/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3558 - y1_output_loss: 0.1270 - y2_output_loss: 0.2283 - y1_output_root_mean_squared_error: 0.3542 - y2_output_root_mean_squared_error: 0.4799 - val_loss: 0.9192 - val_y1_output_loss: 0.2951 - val_y2_output_loss: 0.6452 - val_y1_output_root_mean_squared_error: 0.5366 - val_y2_output_root_mean_squared_error: 0.7946
# Epoch 489/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4431 - y1_output_loss: 0.1484 - y2_output_loss: 0.2940 - y1_output_root_mean_squared_error: 0.3851 - y2_output_root_mean_squared_error: 0.5429 - val_loss: 0.7332 - val_y1_output_loss: 0.1715 - val_y2_output_loss: 0.5579 - val_y1_output_root_mean_squared_error: 0.4144 - val_y2_output_root_mean_squared_error: 0.7493
# Epoch 490/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3465 - y1_output_loss: 0.1387 - y2_output_loss: 0.2181 - y1_output_root_mean_squared_error: 0.3602 - y2_output_root_mean_squared_error: 0.4656 - val_loss: 1.0945 - val_y1_output_loss: 0.3002 - val_y2_output_loss: 0.8205 - val_y1_output_root_mean_squared_error: 0.5566 - val_y2_output_root_mean_squared_error: 0.8858
# Epoch 491/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4220 - y1_output_loss: 0.1332 - y2_output_loss: 0.2869 - y1_output_root_mean_squared_error: 0.3661 - y2_output_root_mean_squared_error: 0.5366 - val_loss: 0.8446 - val_y1_output_loss: 0.1641 - val_y2_output_loss: 0.7243 - val_y1_output_root_mean_squared_error: 0.4014 - val_y2_output_root_mean_squared_error: 0.8267
# Epoch 492/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.2814 - y1_output_loss: 0.1095 - y2_output_loss: 0.1723 - y1_output_root_mean_squared_error: 0.3303 - y2_output_root_mean_squared_error: 0.4152 - val_loss: 0.7060 - val_y1_output_loss: 0.1946 - val_y2_output_loss: 0.5105 - val_y1_output_root_mean_squared_error: 0.4371 - val_y2_output_root_mean_squared_error: 0.7176
# Epoch 493/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.2667 - y1_output_loss: 0.1108 - y2_output_loss: 0.1585 - y1_output_root_mean_squared_error: 0.3330 - y2_output_root_mean_squared_error: 0.3947 - val_loss: 1.0666 - val_y1_output_loss: 0.2526 - val_y2_output_loss: 0.7971 - val_y1_output_root_mean_squared_error: 0.4957 - val_y2_output_root_mean_squared_error: 0.9060
# Epoch 494/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3527 - y1_output_loss: 0.1144 - y2_output_loss: 0.2384 - y1_output_root_mean_squared_error: 0.3398 - y2_output_root_mean_squared_error: 0.4871 - val_loss: 1.1915 - val_y1_output_loss: 0.2178 - val_y2_output_loss: 0.9630 - val_y1_output_root_mean_squared_error: 0.4677 - val_y2_output_root_mean_squared_error: 0.9863
# Epoch 495/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3395 - y1_output_loss: 0.1276 - y2_output_loss: 0.2152 - y1_output_root_mean_squared_error: 0.3522 - y2_output_root_mean_squared_error: 0.4642 - val_loss: 2.1439 - val_y1_output_loss: 0.6980 - val_y2_output_loss: 1.3906 - val_y1_output_root_mean_squared_error: 0.8402 - val_y2_output_root_mean_squared_error: 1.1991
# Epoch 496/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3632 - y1_output_loss: 0.1292 - y2_output_loss: 0.2334 - y1_output_root_mean_squared_error: 0.3603 - y2_output_root_mean_squared_error: 0.4830 - val_loss: 0.7785 - val_y1_output_loss: 0.2080 - val_y2_output_loss: 0.5652 - val_y1_output_root_mean_squared_error: 0.4547 - val_y2_output_root_mean_squared_error: 0.7561
# Epoch 497/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.2857 - y1_output_loss: 0.1127 - y2_output_loss: 0.1712 - y1_output_root_mean_squared_error: 0.3363 - y2_output_root_mean_squared_error: 0.4155 - val_loss: 0.6894 - val_y1_output_loss: 0.1831 - val_y2_output_loss: 0.5021 - val_y1_output_root_mean_squared_error: 0.4279 - val_y2_output_root_mean_squared_error: 0.7116
# Epoch 498/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4076 - y1_output_loss: 0.1317 - y2_output_loss: 0.2739 - y1_output_root_mean_squared_error: 0.3635 - y2_output_root_mean_squared_error: 0.5249 - val_loss: 0.7017 - val_y1_output_loss: 0.1663 - val_y2_output_loss: 0.5459 - val_y1_output_root_mean_squared_error: 0.4041 - val_y2_output_root_mean_squared_error: 0.7338
# Epoch 499/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3243 - y1_output_loss: 0.1100 - y2_output_loss: 0.2123 - y1_output_root_mean_squared_error: 0.3328 - y2_output_root_mean_squared_error: 0.4621 - val_loss: 0.7408 - val_y1_output_loss: 0.1534 - val_y2_output_loss: 0.5753 - val_y1_output_root_mean_squared_error: 0.3874 - val_y2_output_root_mean_squared_error: 0.7685
# Epoch 500/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3066 - y1_output_loss: 0.1191 - y2_output_loss: 0.1905 - y1_output_root_mean_squared_error: 0.3397 - y2_output_root_mean_squared_error: 0.4372 - val_loss: 0.8007 - val_y1_output_loss: 0.2426 - val_y2_output_loss: 0.5582 - val_y1_output_root_mean_squared_error: 0.4945 - val_y2_output_root_mean_squared_error: 0.7458

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 34us/sample - loss: 0.8007 - y1_output_loss: 0.2411 - y2_output_loss: 0.5476 - y1_output_root_mean_squared_error: 0.4945 - y2_output_root_mean_squared_error: 0.7458
# Loss = 0.8006903579482785, Y1_loss = 0.2411354035139084, Y1_mse = 0.49449560046195984, Y2_loss = 0.5476462841033936, Y2_mse = 0.7457643747329712

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
